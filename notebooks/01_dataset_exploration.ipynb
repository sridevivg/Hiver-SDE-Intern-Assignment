# %% [markdown]
# # 01 — Dataset Exploration
#
# **SupportGraph AI — Phase 1**
#
# This notebook provides an interactive interface to the exploration pipeline.
# The canonical, reproducible exploration is in `backend/scripts/explore_dataset.py`.
# This notebook is for visual inspection and ad-hoc analysis.
#
# ---
#
# **Rules:**
# - Do NOT modify the raw DataFrame.
# - Do NOT commit notebook output — clear outputs before committing.
# - All conclusions must be based on actual data.

# %%
import sys
from pathlib import Path

# Add project root to path
PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")

# %%
from backend.app.data.loader import discover_dataset, load_dataset, get_dataset_metadata
from backend.app.data.cleaner import analyze_cleaning_needs
from backend.app.data.explorer import run_exploration

print("Imports OK")

# %%
# Load a sample for quick inspection
filepath, all_csvs = discover_dataset()
print(f"Found: {filepath}")

# Load first 10,000 rows for fast notebook exploration
df = load_dataset(filepath=filepath, nrows=10_000)
print(f"Loaded: {df.shape}")

# %%
df.head()

# %%
df.info()

# %%
# Non-destructive cleaning analysis
cleaning = analyze_cleaning_needs(df)
print(f"Duplicate rows: {cleaning.duplicate_row_count}")
print(f"Total null cells: {cleaning.total_null_cells}")

# %%
# Run full exploration on the sample
result = run_exploration(filepath=filepath, nrows=10_000)
print("Exploration complete")
print(f"Brand candidates: {len(result.brand_candidates)}")
